# %%
from pyspark.sql import SparkSession

df = spark.read.csv("/FileStore/tables/yellow_tripdata_2023_01.csv",
                    header=True,
                    inferSchema=True)

df.write.format("delta").mode("overwrite").save("/mnt/bronze/nyc_taxi")
